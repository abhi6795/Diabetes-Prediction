# %% [markdown]
# # BISI CST2101 Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %% [markdown]
# ### Q1: Import the necessary libraries and briefly explain the use of each library (1 Mark)

# %%
# remove _____ & write the appropriate library name

# importing required libraries:

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# You don't have to explain about these libraries below
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 1: Following libraries are used:

# %% [markdown]
# **NumPy Library (Numerical Python)** is an open source Python library that is used to access the flexible multi-dimensional array object for storage of data and potent mathematical methods for manipulating those arrays of numbers.

# %% [markdown]
# **Pandas Library:** A Python library specially used for data analysis. It include functions like that are used to tranform data into representable form for analysis (cleaning, exploring, manipulating etc.)

# %% [markdown]
# **Seaborn Library** is a library for making statistical graphics and data visualization in Python. It builds on top of matplotlib and integrates closely with pandas data structures.Its plotting functions work with dataframes and arrays that include entire datasets, and they internally carry out the semantic mapping and statistical aggregation required to make useful graphs.

# %% [markdown]
# **Matplot Library (matplotlib.pyplot)** is a plotting library in Python for creating static, animated, and interactive visualizations. It provides a convenient interface for creating a variety of plots such as line plots, scatter plots, bar plots,histogram, power spectra, error charts, etc.
#
# Matplotlib inline is used to display Matplotlib plots directly in a Jupyter Notebook or IPython shell output without saving plots as image files or open them in a separate window.

# %% [markdown]
# ### Q2: Read the given dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name

# importing csv file(diabetes) and difining dataframe with "pima"

pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ### Q3. Show the last 5 records of the dataset (1 Mark)

# %%
#remove ______ and write the appropriate number in the function

# observing last 5 records of 'pima' dataset

pima.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 995            2      173             79             32      474  35.504233
# 996           13      132             70             30      111  35.271769
# 997            3      132             87             44      156  34.794755
# 998            0      140              0              0        0  41.926693
# 999            4       93             59             35       93  45.914499
#
#      DiabetesPedigreeFunction  Age  Outcome
# 995                  0.402867   21        1
# 996                  0.168845   42        1
# 997                  0.765003   29        1
# 998                  0.209833   28        1
# 999                  0.737636   29        1

# %% [markdown]
# ### Q4. Show the first 5 records of the dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name and the number of rows to get in the output

# observing first 5 records of 'pima' dataset

pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Q5. Find the dimension of the `pima` dataframe. What do you understand by the dimension of the dataset? (1 Mark)

# %%
#remove _____ & write the appropriate function name

# Shape or dimension of the dataset

pima.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 5: The dimension or shape of dataset represents the number of rows and number of columns repectively. Here (1000, 9) means pima dataset has 1000 rows and 9 columns.

# %% [markdown]
# ### Q6. Find the size of the `pima` dataframe. (1 Mark)

# %%
#remove _____ & write the appropriate function name

# Size of the dataset

pima.size
# Out:
# 9000

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 6: This function helps to find the size of dataset: (no. of columns x no. of rows): 9000 for pima dataset.

# %% [markdown]
# ### Q7. Display the data types of all the variables in the data set? (1 Mark)

# %%
#remove _____ & write the appropriate function name

# datatype of every variable (feature or column).

pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ### Q8. Are there any missing values in the `pima` dataframe?  Which variables have missing values? (1 Mark)

# %%
#remove _____ & write the appropriate function name

# checking null values.

pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 8: No, there are no null values any of the variable and thats why it shows False.

# %% [markdown]
# ### Q9. Find the summary statistics for all variables except for  `'Outcome'` variable? Choose any one column/variable and explain all the statistical measures. (2 Marks)

# %%
#remove _____ & write the appropriate function name

# analysing the numeric variables.

pima.iloc[:,:8].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean      4.051000   125.21600      69.072000      20.755000    83.086000
# std       3.325576    32.27772      20.465328      16.008599   117.255326
# min       0.000000     0.00000       0.000000       0.000000     0.000000
# 25%       1.000000   102.00000      64.000000       0.000000     0.000000
# 50%       3.000000   122.00000      72.000000      24.000000    23.000000
# 75%       6.000000   146.00000      80.000000      33.000000   133.500000
# max      17.000000   199.00000     122.000000      99.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  1000.000000               1000.000000  1000.000000
# mean     32.664772                  0.494090    33.830000
# std       7.563614                  0.322158    11.268189
# min       0.000000                  0.078000    21.000000
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 9:
#
# Variable: Insulin
#
# (a) count: 1000   This shows the number of records in a particular variable. If the count less that dataset records, then that variable is having missing values. (geere
#
# (b) mean: 83.08 Represents the mean or average of all records of that particular variable.
#
# (c) std: 117.25 Shows the standard deviation in the records of a particular variable.
#
# (d) min: 0.00 shows the minimum value of a particular variable.
#
# (e) max: 846.00  shows the maximum value of a particular variable
#
# (f) 50%: 23.00 this the median of a particular variable.
#
# (g) 25% and 75%: represents the inter-quartile range. Lower limit is represented by 25% and higher limit by 75%. Records with value out of this range are called outliers.

# %% [markdown]
# ### Q10. Plot the distribution plot for the variable `'BloodPressure'`. Write your observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate library name

# plotting distribution plot of blood pressure variable using seaborn library.

sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 10:
#
# From graph we can see that most of the people are having blood pressure in the range of 40 to 100. Maximum people having 75 which is most appropiate one.
#
# But it also shows that some people are having negative and zero blood pressure which is practically not possible. So these records are having error and acts as outliers which has to be imputed to inter-quartile range by mean or median as per the analysis.

# %% [markdown]
# ### Q11. What is the `'BMI'` for the person having the highest `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

# value of BMI for a person having maximum glucose level.

pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 11: BMI of a person having highest glucose level (661) will be 42.9 kg/(height in m)^2

# %% [markdown]
# ### Q12.
# #### 12.1 What is the mean of the variable `'BMI'`?
# #### 12.2 What is the median of the variable `'BMI'`?
# #### 12.3 What is the mode of the variable `'BMI'`?
# #### 12.4 Are the three measures of central tendency equal?
#
# ### (2 Marks)

# %%
#remove _____ & write the appropriate function name

# mean, median and mode of BMI variable.

m1 = pima['BMI'].mean()  #Mean
print(m1)
m2 = pima['BMI'].median()  #Median
print(m2)
m3 = pima['BMI'].mode()[0]  #Mode
print(m3)
# Out:
# 32.664772391408796
# 32.8
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 12:
#
# Mean of BMI: 32.66
# Median of BMI: 32.8
# Mode of BMI: 32.0

# %% [markdown]
# ### Q13. How many women's `'Glucose'` level is above the mean level of `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 449

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 13: 449 women out of 1000 records are having glucose level higher than mean glucose value.

# %% [markdown]
# ### Q14. Create the pairplot for variables `'Glucose'`, `'SkinThickness'` and `'DiabetesPedigreeFunction'`. Write you observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate function and argument names

# plotting pairplots to observe relationships

sns.pairplot(data=pima, x_vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 14:
#
# (a) From pairplot it is observed that the values of outcomes (0 and 1) are uniformly (normal) distributed w.r.t to other input variables.
#
# (b) Many outliers can be observed like records with zero values of BMI, blood pressure, skin thickness.
#
# (c) no varible is highly correlated with other variable.

# %% [markdown]
# ### Q15. Plot the scatterplot between `'Glucose'` and `'Insulin'`. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name

# scatterplot between glucose and insulin variable.

sns.scatterplot(x='Glucose',y='Insulin',data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 15:
#
# Insulin shots are taken by diabetic patients to maintain the glucose level. From the graph we can see the linear relationship between Insulin dose level and the glucose level in body.
#
# Insulin dose depends on the glucose level. Some of the people do not require any insulin and thats why they have zero insulin level.

# %% [markdown]
# ### Q16. Plot the boxplot for the 'Age' variable. Are there outliers? (1 Mark)

# %%
#remove _____ & write the appropriate function and column name 

# Boxplot for age variable

plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 16:
#
# Yes, Age variable have outliers. Age above 65 years are considered outliers.

# %% [markdown]
# ### Q17. Find and visualize the the correlation matrix. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name and run the code

# plotting correlation matrix

corr_matrix = pima.iloc[:,0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.112930       0.127463      -0.080033
# Glucose                      0.112930  1.000000       0.134993       0.050656
# BloodPressure                0.127463  0.134993       1.000000       0.249063
# SkinThickness               -0.080033  0.050656       0.249063       1.000000
# Insulin                     -0.064909  0.334175       0.117369       0.472663
# BMI                          0.012920  0.222138       0.247275       0.387055
# DiabetesPedigreeFunction    -0.025452  0.127004       0.059303       0.214026
# Age                          0.548665  0.255567       0.240416      -0.121236
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.064909  0.012920                 -0.025452
# Glucose                   0.334175  0.222138                  0.127004
# ...

# %%
#remove _____ & write the appropriate function name

# plotting heatmap of correlation matrix.

plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 17:
#
# From the heatmap we can observe the correlation between any two varible and can be helpful to do analysis and find dependency on outcome variable.
#
# Here, 'Age' and 'Pregnancies' is having highest positive correlation (0.55) and lowest was of 'Age' and 'DiabetesPedigreeFunction' (0.0068).

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Q18. Split and scale the data (2 Mark)

# %%
# remove _____ & write the appropriate function variable name

# Split the data into dependent and independent variables

y = pima.Outcome
x = pima.drop('Outcome', axis = 1)

# %%
# remove _____ & write the appropriate function function name

# Using StandarScaler scale the data

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(x)

# %%
# remove _____ & complete the code

# Splitting the data into train and test. Use test size as 15%

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x , y, test_size = 0.15, stratify=y,  random_state = 45)

# %% [markdown]
# ### Q19. Train a Logistic Regression Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
from sklearn.linear_model import LogisticRegression

# Increase max_iter to 1000
logreg = LogisticRegression(max_iter=5000)

# %%
# remove _____ & complete the code

# import the model
from sklearn.linear_model import LogisticRegression

# Instantiate the model
lr = LogisticRegression()

# fit the model on the train set
m = lr.fit(x_train, y_train)

# Predict on x_test
y_pred = m.predict(x_test)

# Evaluate the model
print('Accuracy of Logistic Regression model on the train set: {:.2f}'.format(m.score(x_train, y_train)))
print('Accuracy of the Logictic Regression model on the test set: {:.2f}'.format(m.score(x_test, y_test)))

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of the Logictic Regression model on the test set: 0.76
# C:\Users\Abhi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[62, 13],
#        [23, 52]], dtype=int64)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 19:
#
# For Logistic Regression model: **Accuracy** of model is **76%**

# %% [markdown]
# From confusion matrix: **True Positives: 62,
#                        True Negatives: 52**

# %% [markdown]
# ### Q20. Train a Random Forest Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
#remove _____ & complete the code

# Import the Model
from sklearn.ensemble import RandomForestClassifier

# Instantiate the model. 
rf = RandomForestClassifier(n_estimators=301, max_depth=3)

# fit the model on the train set
m2 = rf.fit(x_train, y_train)

# Predict on x_test
y_pred2 = m2.predict(x_test)

# Evaluate the Model
print('Accuracy of Random Forest model on the train set: {:.2f}'.format(m2.score(x_train, y_train)))
print('Accuracy of Random Forest model on the test set: {:.2f}'.format(m2.score(x_test, y_test)))
confusion_matrix(y_test, y_pred2)
# Out:
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.79
# array([[56, 19],
#        [13, 62]], dtype=int64)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 20:
#
# For Random Forest Model model: **Accuracy** of model is **79% (testing set accuracy)**

# %% [markdown]
# From confusion matrix: **True Positives: 56,
#                        True Negatives: 62**

# %% [markdown]
# ### Q21. Which model performed better? (1 Mark)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 21:

# %% [markdown]
# **Random Forest model** has performed better than logistic regression with an accuracy of **79%.**
